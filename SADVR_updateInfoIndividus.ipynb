# %%
import requests
from SADVR_getTables import mapping, getTable
from SADVR_getInfoIndividus import getInfoIndividus
import pandas as pd

# %%
getTable('individus')
# Out:
#       idsadvr           nom      prenom                        fonction
# 0     in13580       Sygusch      Jurgen            Professeur titulaire  \
# 1     in13581     Perreault  Jacques Y.        Directeur de département
# 2     in13583         Bleau      Gilles                            None
# 3     in13584     Rossignol       Serge              Professeur associé
# 4     in13585        Cardia    Emanuela           Professeure titulaire
# ...       ...           ...         ...                             ...
# 9828  in35952  Simons Pardo      George                       Doctorant
# 9829  in35955         Trinh    Quoc-Huy                            None
# 9830  in35958        Gaudel       Fanny  Coordonnatrice/chargée prjts 1
# 9831  in35959           ?_?         ?_?                            None
# 9832  in35962        Demers     Camille  Aux. de recherche (étudiant/e)
#
#                               courriel
# 0          jurgen.sygusch@umontreal.ca  \
# ...

# %%
ids_individus = [x['idsadvr'] for x in data_individus]

# %%
baseURI = 'https://www.recherche.umontreal.ca/vitrine/rest/api/1.7/umontreal'
res = requests.get('https://recherche.umontreal.ca/vitrine/rest/public/api/1.7/umontreal/id/individu')
res.text
