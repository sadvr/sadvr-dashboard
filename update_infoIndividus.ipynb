# %%
import requests
import json
import pandas as pd
from SADVR_getTables import getTable

def getInfoIndividus(id_individus: list) -> pd.DataFrame :
    """ 
    Cette fonction prend en paramètre une liste d'identifiants associés à des individus inscrits dans le SADVR
    et retourne un DataFrame contenant les informations pour chacun de ces individus.\nNormalement, la liste d'individu
    a été obtenue par une première requête envoyée l'URI 'id/individu'
    """
    baseURI = 'https://www.recherche.umontreal.ca/vitrine/rest/api/1.7/umontreal'

    output = []
    for id in id_individus:
        try:
            uri = f'{baseURI}/info/individu?idsadvr={id}'
            output.append(json.loads(requests.get(uri).text)['data'])

        except Exception as e:
            print(id, e)

    output.to_csv('tables/infoIndividus.csv', index=False)
    return output


def updateInfoIndividus(tableInfoIndividus: pd.DataFrame) -> pd.DataFrame:
    """
    Cette fonction prend en paramètre un dataframe contenant les informaitons sur les individus du SADVR
    et retourne une version actualisée de celui-ci en y ajoutant l'information associée aux individus
    dernièrement ajoutés au SADVR.\nNormalement, le dataframe d'entrée a été obtenu par l'exécution de la 
    fonction getInfoIndividus sur l'ensemble des individus. La requête étant relativement longue à exécuter sur 
    tous les individus à la fois, la présente fonction est conçue pour éviter d'avoir à extraire toutes les
    données à chaque fois et plutôt n'extraire que les nouvelles informations.
    """
    all_ids = [x['idsadvr'] for x in getTable('individus').to_dict('records')]
    current_ids = tableInfoIndividus['idsadvr'].tolist()

    # Extraire la liste des ids qui ne se trouvent pas dans la table SADVR_infoIndividus
    ids = [x for x in all_ids if not x in current_ids]

    # Ajouter les nouveaux ids à la table
    new_info = getInfoIndividus(ids)
    output = pd.concat([tableInfoIndividus, new_info])
    output.to_csv('tables/SADVR_infoIndividus.csv')

    return output


current_info = pd.read_csv('tables/SADVR_infoIndividus.csv')
updateInfoIndividus(current_info)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\camil\OneDrive - Universite de Montreal\CENR\SADVR\CENR__SADVR_Dashboard\update_infoIndividus.ipynb Cell 1 in 5
#      <a href='vscode-notebook-cell:/c%3A/Users/camil/OneDrive%20-%20Universite%20de%20Montreal/CENR/SADVR/CENR__SADVR_Dashboard/update_infoIndividus.ipynb#W1sZmlsZQ%3D%3D?line=46'>47</a>     return output
#      <a href='vscode-notebook-cell:/c%3A/Users/camil/OneDrive%20-%20Universite%20de%20Montreal/CENR/SADVR/CENR__SADVR_Dashboard/update_infoIndividus.ipynb#W1sZmlsZQ%3D%3D?line=49'>50</a> current_info = pd.read_csv('tables/SADVR_infoIndividus.csv')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/camil/OneDrive%20-%20Universite%20de%20Montreal/CENR/SADVR/CENR__SADVR_Dashboard/update_infoIndividus.ipynb#W1sZmlsZQ%3D%3D?line=50'>51</a> updateInfoIndividus(current_info)
#
# c:\Users\camil\OneDrive - Universite de Montreal\CENR\SADVR\CENR__SADVR_Dashboard\update_infoIndividus.ipynb Cell 1 in 4
#      <a href='vscode-notebook-cell:/c%3A/Users/camil/OneDrive%20-%20Universite%20de%20Montreal/CENR/SADVR/CENR__SADVR_Dashboard/update_infoIndividus.ipynb#W1sZmlsZQ%3D%3D?line=39'>40</a> ids = [x for x in all_ids if not x in current_ids]
#      <a href='vscode-notebook-cell:/c%3A/Users/camil/OneDrive%20-%20Universite%20de%20Montreal/CENR/SADVR/CENR__SADVR_Dashboard/update_infoIndividus.ipynb#W1sZmlsZQ%3D%3D?line=41'>42</a> # Ajouter les nouveaux ids à la table
# ---> <a href='vscode-notebook-cell:/c%3A/Users/camil/OneDrive%20-%20Universite%20de%20Montreal/CENR/SADVR/CENR__SADVR_Dashboard/update_infoIndividus.ipynb#W1sZmlsZQ%3D%3D?line=42'>43</a> new_info = getInfoIndividus(ids)
#      <a href='vscode-notebook-cell:/c%3A/Users/camil/OneDrive%20-%20Universite%20de%20Montreal/CENR/SADVR/CENR__SADVR_Dashboard/update_infoIndividus.ipynb#W1sZmlsZQ%3D%3D?line=43'>44</a> output = pd.concat([tableInfoIndividus, new_info])
#      <a href='vscode-notebook-cell:/c%3A/Users/camil/OneDrive%20-%20Universite%20de%20Montreal/CENR/SADVR/CENR__SADVR_Dashboard/update_infoIndividus.ipynb#W1sZmlsZQ%3D%3D?line=44'>45</a> output.to_csv('tables/SADVR_infoIndividus.csv')
#
# c:\Users\camil\OneDrive - Universite de Montreal\CENR\SADVR\CENR__SADVR_Dashboard\update_infoIndividus.ipynb Cell 1 in 2
#      <a href='vscode-notebook-cell:/c%3A/Users/camil/OneDrive%20-%20Universite%20de%20Montreal/CENR/SADVR/CENR__SADVR_Dashboard/update_infoIndividus.ipynb#W1sZmlsZQ%3D%3D?line=19'>20</a>     except Exception as e:
#      <a href='vscode-notebook-cell:/c%3A/Users/camil/OneDrive%20-%20Universite%20de%20Montreal/CENR/SADVR/CENR__SADVR_Dashboard/update_infoIndividus.ipynb#W1sZmlsZQ%3D%3D?line=20'>21</a>         print(id, e)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/camil/OneDrive%20-%20Universite%20de%20Montreal/CENR/SADVR/CENR__SADVR_Dashboard/update_infoIndividus.ipynb#W1sZmlsZQ%3D%3D?line=22'>23</a> output.to_csv('tables/infoIndividus.csv', index=False)
#      <a href='vscode-notebook-cell:/c%3A/Users/camil/OneDrive%20-%20Universite%20de%20Montreal/CENR/SADVR/CENR__SADVR_Dashboard/update_infoIndividus.ipynb#W1sZmlsZQ%3D%3D?line=23'>24</a> return output
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
current_info = pd.read_csv('tables/SADVR_infoIndividus.csv')
current_info
# Out:
#       idsadvr      prenom           nom  in-memoriam sexe
# 0     in13580      Jurgen       Sygusch        False    M  \
# 1     in13581  Jacques Y.     Perreault        False    M
# 2     in13583      Gilles         Bleau        False    M
# 3     in13584       Serge     Rossignol        False    M
# 4     in13585    Emanuela        Cardia        False    F
# ...       ...         ...           ...          ...  ...
# 9827  in35952      George  Simons Pardo        False    M
# 9828  in35955    Quoc-Huy         Trinh        False  NaN
# 9829  in35958       Fanny        Gaudel        False    F
# 9830  in35959         ?_?           ?_?        False  NaN
# 9831  in35962     Camille        Demers        False    A
#
#                  institution paysCode paysNom
# 0     Université de Montréal       CA  Canada  \
# 1     Université de Montréal       CA  Canada
# 2     Université de Montréal       CA  Canada
# 3     Université de Montréal       CA  Canada
# 4     Université de Montréal       CA  Canada
# ...                      ...      ...     ...
# 9827  Université de Montréal       CA  Canada
# 9828  Université de Montréal       CA  Canada
# 9829  Université de Montréal       CA  Canada
# 9830  Université de Montréal       CA  Canada
# 9831  Université de Montréal       CA  Canada
#
#                                            consentement
# 0     {'departements': [], 'facultes': [], 'unitesRe...  \
# 1     {'departements': [], 'facultes': [], 'unitesRe...
# 2     {'departements': [], 'facultes': [], 'unitesRe...
# 3     {'departements': [], 'facultes': [], 'unitesRe...
# 4     {'departements': [], 'facultes': [], 'unitesRe...
# ...                                                 ...
# 9827  {'departements': [], 'facultes': [], 'unitesRe...
# 9828  {'departements': [], 'facultes': [], 'unitesRe...
# 9829  {'departements': [], 'facultes': [], 'unitesRe...
# 9830  {'departements': [], 'facultes': [], 'unitesRe...
# 9831  {'departements': [], 'facultes': [], 'unitesRe...
#
#                                            affichageWeb  ...
# 0     [{'departements': [], 'facultes': [], 'unitesR...  ...  \
# 1     [{'departements': [], 'facultes': [], 'unitesR...  ...
# 2     [{'departements': [], 'facultes': [], 'unitesR...  ...
# 3     [{'departements': [], 'facultes': [], 'unitesR...  ...
# 4     [{'departements': [], 'facultes': [], 'unitesR...  ...
# ...                                                 ...  ...
# 9827  [{'departements': [], 'facultes': [], 'unitesR...  ...
# 9828  [{'departements': [], 'facultes': [], 'unitesR...  ...
# 9829  [{'departements': [], 'facultes': [], 'unitesR...  ...
# 9830  [{'departements': [], 'facultes': [], 'unitesR...  ...
# 9831  [{'departements': [], 'facultes': [], 'unitesR...  ...
#
#                                             publication communication
# 0     <ul>\r\n\t<li>Pour consulter les publications ...           NaN  \
# 1                                                   NaN           NaN
# 2                                                   NaN           NaN
# 3                                                   NaN           NaN
# 4     <p>'Market Work, Housework and Childcare: A Ti...           NaN
# ...                                                 ...           ...
# 9827                                                NaN           NaN
# 9828                                                NaN           NaN
# 9829                                                NaN           NaN
# 9830                                                NaN           NaN
# 9831                                                NaN           NaN
#
#                                               expertise
# 0     [{'secteursRecherche': [{'uid': '6', 'codeLang...  \
# 1     [{'secteursRecherche': [{'uid': '10', 'codeLan...
# 2     [{'secteursRecherche': [{'uid': '6', 'codeLang...
# 3     [{'secteursRecherche': [{'uid': '6', 'codeLang...
# 4     [{'secteursRecherche': [{'uid': '10', 'codeLan...
# ...                                                 ...
# 9827  [{'secteursRecherche': [{'uid': '10', 'codeLan...
# 9828  [{'secteursRecherche': [], 'disciplines': [], ...
# 9829  [{'secteursRecherche': [], 'disciplines': [], ...
# 9830  [{'secteursRecherche': [], 'disciplines': [], ...
# 9831  [{'secteursRecherche': [], 'disciplines': [], ...
#
#                                          expertiseMedia
# 0     [{'typesMedias': [], 'langues': [], 'disciplin...  \
# 1     [{'typesMedias': [{'typeMedia': 'Presse écrite...
# 2     [{'typesMedias': [], 'langues': [], 'disciplin...
# 3     [{'typesMedias': [], 'langues': [], 'disciplin...
# 4                                                    []
# ...                                                 ...
# 9827                                                 []
# 9828                                                 []
# 9829                                                 []
# 9830                                                 []
# 9831                                                 []
#
#                                                    prix
# 0                        [{'vitrine': [], 'autre': []}]  \
# 1                        [{'vitrine': [], 'autre': []}]
# 2                        [{'vitrine': [], 'autre': []}]
# 3     [{'vitrine': [{'idsadvr': 'pr13591', 'nom': 'P...
# 4                        [{'vitrine': [], 'autre': []}]
# ...                                                 ...
# 9827                     [{'vitrine': [], 'autre': []}]
# 9828                     [{'vitrine': [], 'autre': []}]
# 9829                     [{'vitrine': [], 'autre': []}]
# 9830                     [{'vitrine': [], 'autre': []}]
# 9831                     [{'vitrine': [], 'autre': []}]
#
#                                    infosSupplementaires
# 0     [{'categorie': None, 'nom': "19-10-1998 Pourqu...  \
# 1     [{'categorie': None, 'nom': '28-08-2015  Dynam...
# 2                                                    []
# 3     [{'categorie': None, 'nom': 'Des millions pour...
# 4     [{'categorie': None, 'nom': "25-03-2019 L'écon...
# ...                                                 ...
# 9827                                                 []
# 9828                                                 []
# 9829                                                 []
# 9830                                                 []
# 9831                                                 []
#
#                                                 visuels
# 0                                                    []  \
# 1     [{'categorie': 'Photo officielle', 'nom': None...
# 2                                                    []
# 3     [{'categorie': 'Photo officielle', 'nom': None...
# 4     [{'categorie': 'Photo officielle', 'nom': None...
# ...                                                 ...
# 9827                                                 []
# 9828                                                 []
# 9829                                                 []
# 9830                                                 []
# 9831                                                 []
#
#                                      activitesPromotion nomSAD prenomSAD
# 0                                                    []    NaN       NaN
# 1                                                    []    NaN       NaN
# 2                                                    []    NaN       NaN
# 3     [{'categorie': 'Mise en valeur d’une recherche...    NaN       NaN
# 4                                                    []    NaN       NaN
# ...                                                 ...    ...       ...
# 9827                                                 []    NaN       NaN
# 9828                                                 []    NaN       NaN
# 9829                                                 []    NaN       NaN
# 9830                                                 []    NaN       NaN
# 9831                                                 []    NaN       NaN
#
# [9832 rows x 33 columns]

# %%
all_ids = [x['idsadvr'] for x in getTable('individus').to_dict('records')]
current_ids = tableInfoIndividus['idsadvr'].tolist()

# Extraire la liste des ids qui ne se trouvent pas dans la table SADVR_infoIndividus
ids = [x for x in all_ids if not x in current_ids]

# Ajouter les nouveaux ids à la table
new_info = getInfoIndividus(ids)
output = pd.concat([tableInfoIndividus, new_info])
output.to_csv('tables/SADVR_infoIndividus.csv')

return output
